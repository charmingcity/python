# %% [markdown]
# ## OpenDart API 생성 참조 사이트
#
# https://c11.kr/opendart   금융감독원:OPENDART 전자공시 OPEN API 사용하기

# %%
import OpenDartReader # 모듈 불러오기
my_api = "4986a1557361b049169910f293c79c4ee073f75f" # API KEY 지정 
dart = OpenDartReader(my_api) # OpenDartReader 객체 생성하기

# %% [markdown]
# #### List 메서드

# %%
result = dart.list("신한알파리츠", start = "2020-01-01", end = "2020-12-31")
display(result.head()) # 위 5개 행 출력
display(result.shape) # 데이터프레임 구조 출력
# Out:
#   corp_code corp_name stock_code corp_cls            report_nm  \
# 0  01276594    신한알파리츠     293940        Y      사업보고서 (2020.09)
# 1  01276594    신한알파리츠     293940        Y             정기주주총회결과
# 2  01276594    신한알파리츠     293940        Y         기타경영사항(자율공시)
# 3  01276594    신한알파리츠     293940        Y              감사보고서제출
# 4  01276594    신한알파리츠     293940        Y  [기재정정]의결권대리행사권유참고서류
#
#          rcept_no  flr_nm  rcept_dt rm
# 0  20201229000410  신한알파리츠  20201229  연
# 1  20201221800356  신한알파리츠  20201221  유
# 2  20201216801074  신한알파리츠  20201216  유
# 3  20201211800329  신한알파리츠  20201211  유
# 4  20201209000274  신한알파리츠  20201209
# (66, 9)

# %% [markdown]
# #### Document 메서드

# %%
doc = dart.document("20201229000410")
print(doc)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
#
#
# <DOCUMENT xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="dart3.xsd">
#
# <DOCUMENT-HEADER AEXT-CLASS="Y">
# <DOCUMENT-NAME ACODE="11011">사업보고서</DOCUMENT-NAME>
# <FORMULA-VERSION SUBVER="1" ADATE="20200706">4.1</FORMULA-VERSION>
# <COMPANY-NAME AREGCIK="01276594">주식회사 신한알파위탁관리부동산투자회사</COMPANY-NAME>
#
# <SUMMARY>
# <EXTRACTION ACODE="LINK_FLAG" AFEATURE="BOTH">C</EXTRACTION>
# <EXTRACTION ACODE="FIN_TYPE" AFEATURE="BOTH">A</EXTRACTION>
# <EXTRACTION ACODE="CRP_RGS_NO_TEMP" AFEATURE="BOTH">110111-6601135</EXTRACTION>
# </SUMMARY>
# </DOCUMENT-HEADER>
#
# <BODY>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 정정문서 작성시 『정오표』 삽입</COMMENT>
# <LIBRARYLIST>정정신고(보고)-대표이사등의확인.LCommon</LIBRARYLIST>
# </INSERTION>
#
# <COVER>
# <P></P>
# <COVER-TITLE ATOC="Y" AASSOCNOTE="COVER">사 업 보 고 서</COVER-TITLE>
# <P>&cr;&cr;&cr;</P>
# <P USERMARK="F-16">                                    (제 5 기)</P>
#
# <TABLE-GROUP ACLASS="COVER" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="209"></COL>
# <COL WIDTH="153"></COL>
# <COL WIDTH="211"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD CLASS="NORMAL" ROWSPAN="2" ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="218" HEIGHT="60" AUPDATECONT="N">사업연도</TD>
# <TU CLASS="NORMAL" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="162" HEIGHT="30" AUNIT="PERIODFROM" AUNITVALUE="20200401">2020.04.01</TU>
# <TD CLASS="NORMAL" VALIGN="MIDDLE" WIDTH="220" HEIGHT="30" AUPDATECONT="N"> 부터</TD>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TU CLASS="NORMAL" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="162" HEIGHT="30" AUNIT="PERIODTO" AUNITVALUE="20200930">2020.09.30</TU>
# <TD CLASS="NORMAL" VALIGN="MIDDLE" WIDTH="220" HEIGHT="30" AUPDATECONT="N"> 까지</TD>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
#
# <TABLE AFIXTABLE="N" BORDER="0" WIDTH="600" ACLASS="NORMAL">
#
# <COLGROUP>
# <COL WIDTH="191"></COL>
# <COL WIDTH="391"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">금융위원회</TD>
# <TD WIDTH="400" HEIGHT="30" ALIGN="RIGHT"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">한국거래소 귀중</TD>
# <TD WIDTH="400" HEIGHT="30" ALIGN="RIGHT">2020년   12월   29일</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE-GROUP ACLASS="PB_VAL" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="191"></COL>
# <COL WIDTH="391"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="200" HEIGHT="30" AUPDATECONT="N">제출대상법인 유형 :</TD>
# <TU WIDTH="400" HEIGHT="30" AUNIT="PB_TYPE" AUNITVALUE="1">주권상장법인</TU>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30" AUPDATECONT="N"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="200" HEIGHT="30" AUPDATECONT="N">면제사유발생 :</TD>
# <TU WIDTH="400" HEIGHT="30" AUNIT="PB_CAMNT" AUNITVALUE="-">해당사항 없음</TU>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <TABLE AFIXTABLE="N" BORDER="0" WIDTH="600" ACLASS="NORMAL">
#
# <COLGROUP>
# <COL WIDTH="191"></COL>
# <COL WIDTH="391"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">회      사      명 :</TD>
# <TD WIDTH="400" HEIGHT="30">(주)신한알파위탁관리부동산투자회사</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">대   표    이   사 :</TD>
# <TD WIDTH="400" HEIGHT="30">이 준 구</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">본  점  소  재  지 :</TD>
# <TD WIDTH="400" HEIGHT="30">서울시 종로구 종로33, 그랑서울빌딩</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30">(전  화) 02-2158-7400</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30">(홈페이지) http://www.shalphareit.com</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30">작  성  책  임  자 :</TD>
# <TD WIDTH="400" HEIGHT="30">(직  책)부장                  (성  명)윤연석</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
#
# <TD WIDTH="400" HEIGHT="30">(전  화)
# <SPAN>02-2180-0448</SPAN>
# </TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="200" HEIGHT="30"></TD>
# <TD WIDTH="400" HEIGHT="30"></TD>
# </TR>
# </TBODY>
# </TABLE>
# <PGBRK></PGBRK>
# </COVER>
#
# <TOC>
# <TITLE ATOC="N">목     차</TITLE>
# <P></P>
# <PGBRK></PGBRK>
# </TOC>
#
# <SECTION-1 AID="CEO-CERT" ACLASS="MANDATORY" APARTSOURCE="SOURCE">
# <TITLE ATOC="Y" AASSOCNOTE="TTL_CEO_CERT">【 대표이사 등의 확인 】</TITLE>
#
# <APPENDIX ATYPE="IMAGE">
# <COMMENT>◆click◆ 대표이사 등이 서명한 『확인서』 그림파일 삽입</COMMENT>
# </APPENDIX>
#
# <IMAGE>
# <IMG WIDTH="600" HEIGHT="663" ALIGN="CENTER" HSPACE="0">대표이사 등이 서명한 확인서.jpg</IMG>
# <IMG-CAPTION ATOC="N">대표이사 등이 서명한 확인서</IMG-CAPTION>
# </IMAGE>
# <P></P>
# <PGBRK></PGBRK>
# </SECTION-1>
#
# <SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">
# <TITLE ATOC="Y">I. 회사의 개요</TITLE>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-1-0">1. 회사의 개요</TITLE>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="1" ADUPLICATION="N">
# <COMMENT>◆click◆『연결재무제표를작성하는주권상장법인』 삽입</COMMENT>
# <LIBRARYLIST>11011#*연결재무제표를작성하는주권상장법인.dsl</LIBRARYLIST>
#
# <LIBRARY>
# <FILENAME ATYPE="dsl">1_연결재무제표를작성하는주권상장법인</FILENAME>
# <P>가. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 사업보고서, 분기ㆍ반기보고서를 제출하는 경우에 한함)</P>
#
# <TABLE-GROUP ACLASS="SUB_CMPN" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="602" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="292"></COL>
# <COL WIDTH="292"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="301" HEIGHT="30" AUPDATECONT="N"></TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="301" HEIGHT="30" AUNIT="WON" AUNITVALUE="3">(단위 : 백만원)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="1061" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="209"></COL>
# <COL WIDTH="88"></COL>
# <COL WIDTH="255"></COL>
# <COL WIDTH="69"></COL>
# <COL WIDTH="114"></COL>
# <COL WIDTH="189"></COL>
# <COL WIDTH="74"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="N" ADELETE="N">
# <TH WIDTH="218" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">상호</TH>
# <TH WIDTH="97" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">설립일</TH>
# <TH WIDTH="264" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">주소</TH>
# <TH WIDTH="78" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">주요사업</TH>
# <TH WIDTH="123" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">최근사업연도말&cr;자산총액</TH>
# <TH WIDTH="198" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">지배관계 근거</TH>
# <TH WIDTH="83" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">주요종속&cr;회사 여부</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="N">
# <TE WIDTH="218" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="CRP_NM">(주)신한알파용산&cr;위탁관리부동산투자회사</TE>
# <TE WIDTH="97" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="EST_DT">2018.09.11.</TE>
# <TE WIDTH="264" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="ADR">서울시 종로구 종로33, 그랑서울빌딩</TE>
# <TE WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_IND">부동산&cr;임대업</TE>
# <TE WIDTH="123" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="53" ACODE="KEY_IND">176,782</TE>
# <TE WIDTH="198" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="RUL_REL">기업 의결권의 과반수 소유&cr;(회계기준서 1110호)</TE>
# <TE WIDTH="83" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_SUB_COM">O</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE WIDTH="218" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="CRP_NM">(주)신한알파광교&cr;위탁관리부동산투자회사</TE>
# <TE WIDTH="97" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="EST_DT">2019.09.18.</TE>
# <TE WIDTH="264" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="ADR">서울시 종로구 종로33, 그랑서울빌딩</TE>
# <TE WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_IND">부동산&cr;임대업</TE>
# <TE WIDTH="123" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="53" ACODE="KEY_IND">74,579</TE>
# <TE WIDTH="198" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="RUL_REL">상동</TE>
# <TE WIDTH="83" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_SUB_COM">O</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE WIDTH="218" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="CRP_NM">(주)신한케이제1호&cr;위탁관리부동산투자회사(주1)</TE>
# <TE WIDTH="97" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="EST_DT">2020.05.29</TE>
# <TE WIDTH="264" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="ADR">서울시 종로구 종로33, 그랑서울빌딩</TE>
# <TE WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_IND">부동산&cr;임대업</TE>
# <TE WIDTH="123" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="53" ACODE="KEY_IND">307,879</TE>
# <TE WIDTH="198" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="RUL_REL">상동</TE>
# <TE WIDTH="83" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_SUB_COM">O</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE WIDTH="218" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="CRP_NM">(주)신한알파남산&cr;위탁관리부동산투자회사(주1)</TE>
# <TE WIDTH="97" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="EST_DT">2020.06.18</TE>
# <TE WIDTH="264" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="ADR">서울시 종로구 종로33, 그랑서울빌딩</TE>
# <TE WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_IND">부동산&cr;임대업</TE>
# <TE WIDTH="123" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="53" ACODE="KEY_IND">268,991</TE>
# <TE WIDTH="198" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="RUL_REL">상동</TE>
# <TE WIDTH="83" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="M_SUB_COM">O</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="0" WIDTH="1029">
#
# <COLGROUP>
# <COL WIDTH="1020"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="1029" HEIGHT="30">
# <SPAN>주1) 대상 자회사는 설립일로부터 첫 사업연도가 도래하지 않아 가결산 재무제표의 자산총액을 기재하였습니다.</SPAN>
# </TD>
# </TR>
# </TBODY>
# </TABLE>
# <P></P>
# <P>가-1. 연결대상회사의 변동내용</P>
#
# <TABLE-GROUP ACLASS="CONT_CHG" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="602" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="66"></COL>
# <COL WIDTH="174"></COL>
# <COL WIDTH="335"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="N" ADELETE="N">
# <TH WIDTH="75" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="30">구 분</TH>
# <TH WIDTH="183" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="30">자회사</TH>
# <TH WIDTH="344" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="30">사 유</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="75" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="106" AUPDATECONT="N" ROWSPAN="2">신규&cr;연결</TD>
# <TE WIDTH="183" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="NEW_CPY">(주)신한케이제1호&cr;위탁관리부동산투자회사</TE>
# <TE WIDTH="344" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="NEW_RES">당기중 주식취득으로 편입</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="N">
# <TE WIDTH="183" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="NEW_CPY">(주)신한알파남산&cr;위탁관리부동산투자회사</TE>
# <TE WIDTH="344" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="NEW_RES">당기중 주식취득으로 편입</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="75" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="60" AUPDATECONT="N" ROWSPAN="2">연결&cr;제외</TD>
# <TE WIDTH="183" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="EXP_CPY">-</TE>
# <TE WIDTH="344" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="EXP_RES">-</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="N">
# <TE WIDTH="183" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="EXP_CPY">-</TE>
# <TE WIDTH="344" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="EXP_RES">-</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# </LIBRARY>
# </INSERTION>
# <P></P>
# <P>나. 회사의 법적, 상업적 명칭&cr;당사의 명칭은 '주식회사 신한알파위탁관리부동산투자회사'라고 표기합니다. 또한  영문으로는 'Shinhan Alpha REIT Co,. Ltd.' 라고 표기합니다.&cr;&cr;다. 설립일자 및 존속기간</P>
# <P>당사는 2017년 12월 18일에 설립되었으며, 2018년 8월 8일자로 유가증권시장에 상장하였습니다. 당사의 존속기간은 설립일로부터 40년입니다.&cr;&cr;라. 본사의 주소, 전화번호, 홈페이지 주소&cr;- 주소 : 서울특별시 종로구 종로33, 18층 (청진동, 그랑서울빌딩)&cr;- 전화번호 : 02-2158-7400&cr;- 홈페이지 : http://www.shalphareit.com&cr;&cr;마. 회사사업 영위의 근거가 되는 법률&cr;- 자산을 부동산에 투자하여 운영하는 것을 주된 목적으로 하여 부동산투자회사법에 따라 설립되었습니다.&cr;&cr;바. 중소기업해당여부&cr;- 회사는 중소기업기본법 제2조에 의한 중소기업에 해당되지 않습니다.&cr;&cr;사. 주요사업의 내용&cr;- 회사는 부동산임대업을 주요 사업으로 하고 있습니다.&cr; 기타의 자세한 사항은 동 보고서의 'Ⅱ. 사업의 내용’을 참조하시기 바랍니다.</P>
# <P>&cr;아. 회사가 속해 있는 기업집단 및 계열회사에 관한 사항&cr;- 기업집단 및 계열회사에 관한 사항은 동 보고서의 'Ⅸ. 계열회사 등에 관한 사항'을 참조하시기 바랍니다. &cr;&cr;자. 신용평가에 관한 사항&cr;- 최근 3년간 신용평가에 관한 내용은 없습니다.&cr;</P>
# <P>차. 회사의 주권상장(또는 등록ㆍ지정)여부 및 특례상장에 관한 사항</P>
#
# <TABLE-GROUP ACLASS="SPC_CRT" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="602" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="165"></COL>
# <COL WIDTH="165"></COL>
# <COL WIDTH="104"></COL>
# <COL WIDTH="132"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="N" ADELETE="N">
# <TH WIDTH="174" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">주권상장&cr;(또는 등록ㆍ지정)여부</TH>
# <TH WIDTH="174" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">주권상장&cr;(또는 등록ㆍ지정)일자</TH>
# <TH WIDTH="113" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">특례상장 등&cr;여부</TH>
# <TH WIDTH="141" VALIGN="MIDDLE" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ALIGN="CENTER" HEIGHT="53">특례상장 등&cr;적용법규</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TE WIDTH="174" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="SPC_CHK">상장</TE>
# <TU WIDTH="174" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUNIT="SPC_DATE" AUNITVALUE="20180808">2018.08.08</TU>
# <TE WIDTH="113" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="SPC_CHP">-</TE>
# <TE WIDTH="141" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="SPC_LAW">-</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
# <P></P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-2-0">2. 회사의 연혁</TITLE>
# <P></P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="1" WIDTH="626">
#
# <COLGROUP>
# <COL WIDTH="135"></COL>
# <COL WIDTH="473"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">시기</TH>
# <TH WIDTH="482" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">내용</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2017년 12월 18일 </TD>
# <TD WIDTH="482" HEIGHT="30">회사 발기설립(자기자본 3억원)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 02월 09일 </TD>
# <TD WIDTH="482" HEIGHT="30">자산보관위탁계약 체결 (㈜국민은행)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 03월 15일 </TD>
# <TD WIDTH="482" HEIGHT="30">일반사무관리위탁계약 체결 (신한아이타스㈜)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 03월 21일 </TD>
# <TD WIDTH="482" HEIGHT="30">국토교통부 위탁관리부동산투자회사 영업인가 승인</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 04월 20일 </TD>
# <TD WIDTH="482" HEIGHT="30">1차 유상증자 (보통주식 1,842,859주)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 04월 24일 </TD>
# <TD WIDTH="482" HEIGHT="30">자산관리위탁계약 체결 (신한리츠운용㈜)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 04월 27일</TD>
# <TD WIDTH="482" HEIGHT="30">2차 유상증자 (보통주식 13,163,264주, 우선주 4,000,000주)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="53" ALIGN="CENTER" VALIGN="MIDDLE">2018년 04월 27일</TD>
#
# <TD WIDTH="482" HEIGHT="53">
# <SPAN>투자부동산</SPAN>
# <SPAN>(</SPAN>
# <SPAN>판교 크래프톤타워</SPAN>
# <SPAN>) 취득 </SPAN>
# <SPAN>및 코크렙더프라임위탁관리부동산투자회사의 보통주 양수 완료</SPAN>
# </TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">
# <SPAN>2018년 06</SPAN>
# <SPAN>월 </SPAN>
# <SPAN>07</SPAN>
# <SPAN>일 </SPAN>
# </TD>
# <TD WIDTH="482" HEIGHT="30">유가증권시장 상장예비심사 승인 통보</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 07월 31일</TD>
# <TD WIDTH="482" HEIGHT="30">3차 유상증자 (보통주식 22,800,000주)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 08월 08일</TD>
# <TD WIDTH="482" HEIGHT="30">유가증권시장 상장</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2018년 10월 31일</TD>
# <TD WIDTH="482" HEIGHT="30">투자부동산(용산 더프라임타워) 매입 완료</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2019년 01월 30일</TD>
# <TD WIDTH="482" HEIGHT="30">4차 유상증자 (보통주식 9,524,000주)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2019년 02월 15일</TD>
# <TD WIDTH="482" HEIGHT="30">유가증권시장 추가상장</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2020년 03월 04일</TD>
# <TD WIDTH="482" HEIGHT="30">투자부동산(을지로 대일빌딩) 매입 완료</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2020년 05월 27일</TD>
# <TD WIDTH="482" HEIGHT="30">5차 유상증자 (보통주식 4,700,000주)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2020년 06월 09일</TD>
# <TD WIDTH="482" HEIGHT="30">유가증권시장 추가상장</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2020년 08월 26일</TD>
# <TD WIDTH="482" HEIGHT="30">투자부동산(트윈시티 남산) 매입 완료</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="144" HEIGHT="30" ALIGN="CENTER" VALIGN="MIDDLE">2020년 09월 24일</TD>
# <TD WIDTH="482" HEIGHT="30">투자부동산(신한L타워) 매입 완료</TD>
# </TR>
# </TBODY>
# </TABLE>
# <P>&cr;가. 회사의 본점소재지 및 그 변경</P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="1" WIDTH="619">
#
# <COLGROUP>
# <COL WIDTH="140"></COL>
# <COL WIDTH="379"></COL>
# <COL WIDTH="73"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH WIDTH="149" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">일자</TH>
# <TH WIDTH="388" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">본 점 소 재 지</TH>
# <TH WIDTH="82" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">비   고</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="149" ALIGN="CENTER" HEIGHT="30">2017년 12월 18일</TD>
# <TD WIDTH="388" ALIGN="CENTER" HEIGHT="30">서울특별시 종로구 종로33, 18층 (청진동, 그랑서울빌딩)</TD>
# <TD WIDTH="82" ALIGN="CENTER" HEIGHT="30">회사 설립</TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <P>&cr;나. 경영진의 중요한 변동&cr;
# <SPAN></SPAN>
# <SPAN>- </SPAN>
# <SPAN>보고서</SPAN>
# <SPAN> </SPAN>
# <SPAN>기</SPAN>
# <SPAN>준일 </SPAN>
# <SPAN>당</SPAN>
# <SPAN>사의 이사회는 대표이사 1인(이준구), 기타비상무이사 6인(허강진, 윤희준, </SPAN>
# <SPAN></SPAN>
# <SPAN></SPAN>
# <SPAN></SPAN>
# <SPAN>박</SPAN>
# <SPAN>민호, 정구영, 민병강, 나은경), 총 </SPAN>
# <SPAN>7인의 이사로 구성되어 있습니다.</SPAN>
# </P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="1" WIDTH="619">
#
# <COLGROUP>
# <COL WIDTH="146"></COL>
# <COL WIDTH="146"></COL>
# <COL WIDTH="146"></COL>
# <COL WIDTH="145"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">일자</TH>
# <TH WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">직위</TH>
# <TH WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">성명</TH>
# <TH WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" HEIGHT="30">비고</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">2017년 12월 18일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">대표이사&cr;감사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">이준구&cr;김종수</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">회사 설립</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">2018년 04월 20일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">기타비상무이사&cr;기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">김선영&cr;나은경</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">취임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">2018년 05월 14일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">기타비상무이사&cr;기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">김선영&cr;나은경</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">사임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="145">2018년 05월 14일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="145">기타비상무이사&cr;기타비상무이사&cr;기타비상무이사&cr;기타비상무이사&cr;기타비상무이사&cr;기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="145">손두호&cr;허강진&cr;남민정&cr;윤희준&cr;이태석&cr;이창국</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="145">취임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">2018년 12월 21일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">이태석</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">사임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">2018년 12월 21일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">지광욱</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">취임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">2019년 6월 21일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">남민정&cr;지광욱</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">사임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">2019년 6월 21일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">박준태&cr;강현수</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53">취임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">2020년 6월 25일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">손두호&cr;박준태&cr;이창국&cr;강현수</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">사임</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">2020년 6월 25일</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">기타비상무이사</TD>
# <TD WIDTH="155" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">박민호&cr;정구영&cr;민병강&cr;나은경</TD>
# <TD WIDTH="154" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="99">취임</TD>
# </TR>
# </TBODY>
# </TABLE>
# <P>&cr;다. 최대주주의 변동</P>
# <P>- 공시서류작성기준일 현재 최대주주는 유진드림스퀘어전문투자형사모투자신탁34호(신탁업자 (주)국민은행)이며 보통주식 4,081,632주를 보유하고 있습니다.&cr;&cr;라. 상호의 변경</P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="1" WIDTH="608">
#
# <COLGROUP>
# <COL WIDTH="155"></COL>
# <COL WIDTH="302"></COL>
# <COL WIDTH="124"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH WIDTH="164" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">일자</TH>
#
# <TH WIDTH="311" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">
# <P>상호</P>
# </TH>
#
# <TH WIDTH="133" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">
# <P>비 고</P>
# </TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="164" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">
# <P>2017년 12월 18일</P>
# </TD>
# <TD WIDTH="311" ALIGN="CENTER" HEIGHT="30">㈜신한케이리츠위탁관리부동산투자회사</TD>
#
# <TD WIDTH="133" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">
# <P>설립 시</P>
# </TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="164" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">
# <P>2018년 01월 29일</P>
# </TD>
#
# <TD WIDTH="311" ALIGN="CENTER" HEIGHT="30">
# <P>㈜신한알파위탁관리부동산투자회사</P>
# </TD>
# <TD WIDTH="133" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">브랜드 명칭 변경</TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <P>&cr;마. 회사가 화의, 회사정리절차 그 밖에 이에 준하는 절차를 밟은 적이 있거나 현재 진행중인 경우 그 내용과 결과&cr;- 해당사항 없음.&cr;&cr;바. 회사가 합병등을 한 경우 그 내용&cr;- 해당사항 없음.&cr;&cr;사. 회사의 업종 또는 주된 사업의 변화&cr;- 해당사항 없음.&cr;&cr;아. 그 밖에 경영활동과 관련된 중요한 사항의 발생내용
# <SPAN USERMARK=" 0X0000FF">&cr;</SPAN>
# <SPAN>- 해당사항 없음.&cr;</SPAN>
# </P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-3-0">3. 자본금 변동사항</TITLE>
# <P></P>
# <P>가. 증자(감자)현황</P>
#
# <TABLE-GROUP ACLASS="INC_STAT" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="598" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="70"></COL>
# <COL WIDTH="142"></COL>
# <COL WIDTH="58"></COL>
# <COL WIDTH="292"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="79" HEIGHT="30" AUPDATECONT="N">(기준일 : </TD>
# <TU ALIGN="CENTER" VALIGN="BOTTOM" WIDTH="151" HEIGHT="30" AUNIT="BASE_DT" AUNITVALUE="20200930">2020.09.30</TU>
# <TD VALIGN="BOTTOM" WIDTH="67" HEIGHT="30" AUPDATECONT="N">)</TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="301" HEIGHT="30" AUNIT="WONSTOCK" AUNITVALUE="1">(단위 : 원, 주)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="733" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="83"></COL>
# <COL WIDTH="149"></COL>
# <COL WIDTH="89"></COL>
# <COL WIDTH="83"></COL>
# <COL WIDTH="69"></COL>
# <COL WIDTH="81"></COL>
# <COL WIDTH="116"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주식발행&cr;(감소)일자</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">발행(감소)&cr;형태</TH>
# <TH COLSPAN="5" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="483" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">발행(감소)한 주식의 내용</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주식의 종류</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">수량</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="78" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주당&cr;액면가액</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="90" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주당발행&cr;(감소)가액</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="125" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비고</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="N">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20171218">2017.12.18</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="-">-</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">보통주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">60,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">5,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">5,000</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">발기인출자</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20180316">2018.03.16</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="12">주식분할</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">보통주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">240,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">-</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">액면분할</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20180421">2018.04.21</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="02">유상증자(주주배정)</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">보통주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">1,842,859</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">5,535</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">사모 (보통주식)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20180427">2018.04.27</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="04">유상증자(제3자배정)</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">보통주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">13,163,264</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">4,900</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">사모 (보통주식)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20180427">2018.04.27</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="04">유상증자(제3자배정)</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">종류주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">4,000,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">15,000</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">사모 (종류주식)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20180731">2018.07.31</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="01">유상증자(일반공모)</TU>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">보통주식</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">22,800,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">5,000</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">공모 (보통주식)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20190129">2019.01.29</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="02">유상증자(주주배정)</TU>
#
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">
# <SPAN USERMARK=" 0X0000FF"></SPAN>보통주식
# </TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">9,524,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">5,100</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">공모 (보통주식)</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" AUNIT="INC_DT" AUNITVALUE="20200527">2020.05.27</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="158" HEIGHT="30" AUNIT="INC_DR_KND" AUNITVALUE="02">유상증자(주주배정)</TU>
#
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="98" HEIGHT="30" ACODE="INC_STK_KND">
# <SPAN USERMARK=" 0X0000FF"></SPAN>보통주식
# </TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="92" HEIGHT="30" ACODE="INC_CNT">4,700,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="78" HEIGHT="30" ACODE="INC_PAR_AMT">1,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="90" HEIGHT="30" ACODE="INC_SL_AMT">5,860</TE>
# <TD VALIGN="MIDDLE" WIDTH="125" HEIGHT="30">공모 (보통주식)</TD>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 『미상환 전환사채 발행현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*미상환전환사채발행현황.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 『미상환 신주인수권부사채 등 발행현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*미상환신주인수권부사채등발행현황.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 『미상환 전환형 조건부자본증권 등 발행현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*미상환전환형조건부자본증권등발행현황.dsl</LIBRARYLIST>
# </INSERTION>
# <P></P>
# <P></P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-4-0">4. 주식의 총수 등</TITLE>
# <P></P>
# <P>가. 주식의 총수 현황</P>
#
# <TABLE-GROUP ACLASS="TOT_STK" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="663" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="71"></COL>
# <COL WIDTH="143"></COL>
# <COL WIDTH="97"></COL>
# <COL WIDTH="316"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="80" HEIGHT="30" AUPDATECONT="N">(기준일 : </TD>
# <TU ALIGN="CENTER" VALIGN="BOTTOM" WIDTH="152" HEIGHT="30" AUNIT="BASE_DT" AUNITVALUE="20200930">2020.09.30</TU>
# <TD VALIGN="BOTTOM" WIDTH="106" HEIGHT="30" AUPDATECONT="N">)</TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="325" HEIGHT="30" AUNIT="STOCK" AUNITVALUE="1">(단위 : 주)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="665" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="25"></COL>
# <COL WIDTH="204"></COL>
# <COL WIDTH="96"></COL>
# <COL WIDTH="96"></COL>
# <COL WIDTH="95"></COL>
# <COL WIDTH="95"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ROWSPAN="2" COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="247" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">구  분</TH>
# <TH COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="314" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">주식의 종류</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="104" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비고</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACOPYCOL="N" ACODE="STK_KND_TOT" ADELETECOL="N" AMOVECOL="N">보통주</TE>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACOPYCOL="Y" ACODE="STK_KND_TOT" ADELETECOL="Y" AMOVECOL="N">종류주</TE>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">합계</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅰ. 발행할 주식의 총수</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK1">750,000,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK1">250,000,000</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_ISU_STK1">1,000,000,000</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅱ. 현재까지 발행한 주식의 총수</TD>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK2">
# <SPAN USERMARK=" 0X0000FF"></SPAN>52,330,123
# </TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK2">4,000,000</TE>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_ISU_STK2">
# <SPAN USERMARK=" 0X0000FF"></SPAN>56,330,123
# </TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE1">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅲ. 현재까지 감소한 주식의 총수</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="TOT_RST">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="TOT_RST">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_RST">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD ROWSPAN="4" VALIGN="MIDDLE" WIDTH="34" HEIGHT="120" AUPDATECONT="N"></TD>
# <TD VALIGN="MIDDLE" WIDTH="213" HEIGHT="30" AUPDATECONT="N"> 1. 감자</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="RDC_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="RDC_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_RDC_CNT">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE3">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="MIDDLE" WIDTH="213" HEIGHT="30" AUPDATECONT="N"> 2. 이익소각</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="DST_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="DST_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_DST_CNT">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE4">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="MIDDLE" WIDTH="213" HEIGHT="30" AUPDATECONT="N"> 3. 상환주식의 상환</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="RFD_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="RFD_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_RFD_CNT">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE5">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="MIDDLE" WIDTH="213" HEIGHT="30" AUPDATECONT="N"> 4. 기타</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ETC_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ETC_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_ETC_CNT">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE6">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅳ. 발행주식의 총수 (Ⅱ-Ⅲ)</TD>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK3">
# <SPAN USERMARK=" 0X0000FF"></SPAN>52,330,123
# </TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="ISU_STK3">4,000,000</TE>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_ISU_STK3">
# <SPAN>56,330,123</SPAN>
# </TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE7">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅴ. 자기주식수</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="TRS_STK">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="TRS_STK">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_TRS_STK">-</TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE8">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="2" VALIGN="MIDDLE" WIDTH="247" HEIGHT="30" AUPDATECONT="N"> Ⅵ. 유통주식수 (Ⅳ-Ⅴ)</TD>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="FLT_STK">
# <SPAN USERMARK=" 0X0000FF"></SPAN>52,330,123
# </TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="105" HEIGHT="30" ACODE="FLT_STK">4,000,000</TE>
#
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ACODE="SUM_FLT_STK">
# <SPAN></SPAN>
# <SPAN>56,330,123</SPAN>
# </TE>
# <TE VALIGN="MIDDLE" WIDTH="104" HEIGHT="30" ALIGN="CENTER" ACODE="NOTE9">(주1)</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="0" WIDTH="1029">
#
# <COLGROUP>
# <COL WIDTH="1020"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="1029" HEIGHT="53">
# <SPAN>주1) 당사는 상장일 전 1년 이내 사모로 발행한 보통주식 15,306,123주 및 종류주식(우선주) 4,000,000주에 대해 발행일로부터 1년간 보호예수를 하였고, 2019년 4월 27일자로 해당 주식의 보호예수기간이 만료되었습니다.</SPAN>
# </TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 『자기주식 취득 및 처분 현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*자기주식취득및처분현황.dsl</LIBRARYLIST>
# </INSERTION>
# <P></P>
#
# <INSERTION ABASISNUMBER="LE0" AFREQUENCY="1" ADUPLICATION="Y">
# <COMMENT>◆click◆ 『종류주식(명칭) 발행현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*종류주식발행현황.dsl</LIBRARYLIST>
#
# <LIBRARY>
# <FILENAME ATYPE="dsl">24_종류주식발행현황</FILENAME>
# <P>나. 종류주식(명칭) 발행현황</P>
#
# <TABLE-GROUP ACLASS="ISS_CURR" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="291"></COL>
# <COL WIDTH="291"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="300" HEIGHT="30" AUPDATECONT="N"></TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="300" HEIGHT="30" AUNIT="WON" AUNITVALUE="1">(단위 : 원)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="63"></COL>
# <COL WIDTH="76"></COL>
# <COL WIDTH="134"></COL>
# <COL WIDTH="141"></COL>
# <COL WIDTH="141"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" COLSPAN="3" AUPDATECONT="N">발행일자</TD>
# <TU WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUNIT="ISS_DATE" AUNITVALUE="20180427" COLSPAN="2">2018.04.27</TU>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" COLSPAN="3" AUPDATECONT="N">주당 발행가액(액면가액)</TD>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_PRC">15,000</TE>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_PRCK">1,000</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" COLSPAN="3" AUPDATECONT="N">발행총액(발행주식수)</TD>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_TOT">60,000,000,000</TE>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_TOTK">4,000,000 </TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" COLSPAN="3" AUPDATECONT="N">현재 잔액(현재 주식수)</TD>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_PNT">60,000,000,000</TE>
# <TE WIDTH="150" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30" ACODE="ISS_PNTK">4,000,000 </TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="72" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="733" ROWSPAN="12" AUPDATECONT="N">주식의&cr;내용</TD>
# <TD WIDTH="228" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="122" COLSPAN="2" AUPDATECONT="N">이익배당에 관한 사항</TD>
#
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="122" ACODE="STK_BET" COLSPAN="2">
# <SPAN>액면금액(1,000원)의 15배에 연 5.5%(단 회사의 상장을 위한 최초 공모 모집액 납입 완료일까지는 연 5.9%</SPAN>
# <SPAN>)을 적용하여 계산한 금액을 보통주식 보다 우선하여 </SPAN>
# <SPAN>분배함</SPAN>
# <SPAN> (누적적, 비참가적)</SPAN>
# </TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="228" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="196" COLSPAN="2" AUPDATECONT="N">잔여재산분배에 관한 사항</TD>
#
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="196" ACODE="STK_PRO" COLSPAN="2">
# <P USERMARK="F-GL11">다음과 같은 순서에 따라 잔여재산을 분배</P>
# <P USERMARK="F-GL11">1.종류주식에 대한 누적된 미배당 금액이 있는 경우 그 미배당된 금액 상당액</P>
# <P USERMARK="F-GL11">2.종류주식에 대한 발행가액 상당액</P>
# <P USERMARK="F-GL11">3.상기 1,2번 사항에 대한 분배를 하고  남은 잔여재산이 있는 경우 보통주식에 대하여 분배함</P>
# </TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="85" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="173" ROWSPAN="5" AUPDATECONT="N">상환에&cr;관한 사항</TD>
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUPDATECONT="N">상환조건</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_REP" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUPDATECONT="N">상환방법</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_WAY" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUPDATECONT="N">상환기간</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_DAT" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUPDATECONT="N">주당 상환가액</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_PRC" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" AUPDATECONT="N">1년 이내&cr;상환 예정인 경우</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="STK_ONE" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="85" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="212" ROWSPAN="4" AUPDATECONT="N">전환에&cr;관한 사항</TD>
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="76" AUPDATECONT="N">전환조건&cr;(전환비율 변동여부 포함)</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="76" ACODE="STK_CHA" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" AUPDATECONT="N">전환청구기간</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_CDA" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" AUPDATECONT="N">전환으로 발행할&cr;주식의 종류</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="STK_KID" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="143" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" AUPDATECONT="N">전환으로&cr;발행할 주식수</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="STK_CHT" COLSPAN="2">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="228" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" COLSPAN="2" AUPDATECONT="N">의결권에 관한 사항</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30" ACODE="STK_VOT" COLSPAN="2">의결권 없음</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" COLSPAN="3" AUPDATECONT="N">기타 투자 판단에 참고할 사항&cr;(주주간 약정 및 재무약정 사항 등)</TD>
# <TE WIDTH="300" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACODE="ISS_ETC" COLSPAN="2">-</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
# </LIBRARY>
# </INSERTION>
# <P></P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-5-0">5. 의결권 현황</TITLE>
# <P></P>
#
# <TABLE-GROUP ACLASS="VOT_STK" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="70"></COL>
# <COL WIDTH="142"></COL>
# <COL WIDTH="58"></COL>
# <COL WIDTH="294"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="79" HEIGHT="30" AUPDATECONT="N">(기준일 : </TD>
# <TU ALIGN="CENTER" VALIGN="BOTTOM" WIDTH="151" HEIGHT="30" AUNIT="BASE_DT" AUNITVALUE="20200930">2020.09.30</TU>
# <TD VALIGN="BOTTOM" WIDTH="67" HEIGHT="30" AUPDATECONT="N">)</TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="303" HEIGHT="30" AUNIT="STOCK" AUNITVALUE="1">(단위 : 주)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="229"></COL>
# <COL WIDTH="84"></COL>
# <COL WIDTH="136"></COL>
# <COL WIDTH="115"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="238" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">구     분</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="93" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주식의 종류</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="145" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주식수</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="124" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비고</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="238" HEIGHT="60" AUPDATECONT="N">발행주식총수(A)</TD>
# ...
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">2호. 자본준비금 감액 결의의 건 </TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28">
# <SPAN USERMARK="F-10">3호. 제1기 재무제표 승인의 건</SPAN>
# </TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">4호. 이사 선임의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">5호. 제2기 이사보수 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">6호. 제2기 감사보수 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="104" VALIGN="MIDDLE" HEIGHT="168" ROWSPAN="6" ALIGN="CENTER">
# <SPAN USERMARK="F-10">정기주주총회&cr;(2019.06.21)</SPAN>
# </TD>
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">1호. 제2기 재무제표 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">
# <SPAN>2호. 제3기 사업계획 승인의 건</SPAN>
# </TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">3호. 정관 일부 개정 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">4호. 이사 선임의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">5호. 제3기 이사보수 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="28" USERMARK="F-10">6호. 제3기 감사보수 승인의 건</TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10">
# <SPAN>원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="28" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="104" VALIGN="MIDDLE" HEIGHT="49" ALIGN="CENTER" USERMARK="F-10">임시주주총회&cr;(2019.06.21)</TD>
#
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="49" USERMARK="F-10">
# <SPAN>1호. </SPAN>
# <SPAN>정관 일부 개정 승인의 건</SPAN>
# </TD>
#
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="49">
# <SPAN USERMARK="F-10">원안대로 승인</SPAN>
# </TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="49" USERMARK="F-10">종류주&cr;주주총회</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="104" VALIGN="MIDDLE" HEIGHT="133" ALIGN="CENTER" USERMARK="F-10">정기주주총회&cr;(2019.12.19)</TD>
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="133" USERMARK="F-10">1호. 제3기 재무제표 승인의 건&cr;2호. 제4기 사업계획 승인의 건&cr;3호. 정관 일부 개정 승인의 건&cr;4호. 자산관리위탁계약서 변경체결 승인의 건&cr;5호. 제4기 이사보수 승인의 건&cr;6호. 제4기 감사보수 승인의 건</TD>
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="133" USERMARK="F-10">원안대로 승인</TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="133" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="104" VALIGN="MIDDLE" HEIGHT="154" ALIGN="CENTER" USERMARK="F-10">정기주주총회&cr;(2020.06.25)</TD>
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="154" USERMARK="F-10">1호. 제4기 재무제표 승인의 건&cr;2호. 사업계획 승인의 건&cr;3호. 차입계획 승인의 건&cr;4호. 자산보관위탁계약서 변경체결의 건&cr;5호. 이사 선임의 건&cr;6호. 제5기 이사보수 승인의 건&cr;7호. 제5기 감사보수 승인의 건</TD>
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="154" USERMARK="F-10">원안대로 승인</TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="154" USERMARK="F-10"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="104" VALIGN="MIDDLE" HEIGHT="133" ALIGN="CENTER" USERMARK="F-10">정기주주총회&cr;(2020.12.21)</TD>
# <TD WIDTH="300" VALIGN="MIDDLE" HEIGHT="133" USERMARK="F-10">1호. 제5기 재무제표 승인의 건&cr;2호. 사업계획 승인의 건&cr;3호. 차입계획 승인의 건&cr;4호. 특별관계자와의 거래 승인의 건&cr;5호. 제6기 이사보수 승인의 건&cr;6호. 제6기 감사보수 승인의 건</TD>
# <TD WIDTH="138" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="133" USERMARK="F-10">원안대로 승인</TD>
# <TD WIDTH="89" ALIGN="CENTER" HEIGHT="133"></TD>
# </TR>
# </TBODY>
# </TABLE>
# <P>&cr;</P>
#
# <P>
# <SPAN USERMARK="F-16 0XFF1200 B">2. 우발채무 등</SPAN>
# </P>
#
# <P>
# <SPAN USERMARK=" 0X1814FF">&cr;</SPAN>가. 중요한 소송사건
# </P>
# <P>- 해당사항이 없습니다.&cr;&cr;나. 견질 또는 담보용 어음, 수표 현황&cr;- 해당사항이 없습니다.&cr;</P>
#
# <P>
# <SPAN>다. 채무보증 현황</SPAN>
# <SPAN>&cr;</SPAN>
# <SPAN>- </SPAN>
# <SPAN></SPAN>
# <SPAN>당기말 현재 담보</SPAN>
# <SPAN>로 제공된 자산의 내용은 다음과 같습니다.</SPAN>
# </P>
#
# <TABLE WIDTH="810" BORDER="0" ACLASS="NORMAL" AFIXTABLE="N">
#
# <COLGROUP>
# <COL WIDTH="801"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="810" ALIGN="RIGHT" HEIGHT="30">(단위: 백만원)</TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE BORDER="1" WIDTH="825" ACLASS="NORMAL" AFIXTABLE="N">
#
# <COLGROUP>
# <COL WIDTH="69"></COL>
# <COL WIDTH="152"></COL>
# <COL WIDTH="235"></COL>
# <COL WIDTH="69"></COL>
# <COL WIDTH="84"></COL>
# <COL WIDTH="84"></COL>
# <COL WIDTH="69"></COL>
# </COLGROUP>
#
# <THEAD ALIGN="LEFT" VALIGN="TOP">
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">담보&cr;제공자산</TH>
# <TH WIDTH="161" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">담보권의 종류</TH>
# <TH WIDTH="244" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">담보권자</TH>
# <TH WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">장부가액</TH>
# <TH WIDTH="93" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">채권최고액</TH>
# <TH WIDTH="93" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">관련 채무</TH>
# <TH WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N">관련 &cr;채무금액</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ROWSPAN="2" WIDTH="78" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="60">토지,&cr;건물</TD>
# <TD WIDTH="161" VALIGN="MIDDLE" HEIGHT="30">근저당권 및 전세권</TD>
#
# <TD WIDTH="244" VALIGN="MIDDLE" HEIGHT="30">
# <SPAN></SPAN>
# <SPAN>㈜크래프톤 등 13개 임차인</SPAN>
# <SPAN></SPAN>
# <SPAN></SPAN>
# <SPAN></SPAN>
# </TD>
#
# <TD ROWSPAN="2" WIDTH="78" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="60">
# <SPAN>539,373</SPAN>
# </TD>
# <TD WIDTH="93" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30">14,243</TD>
# <TD WIDTH="93" VALIGN="MIDDLE" ALIGN="CENTER" HEIGHT="30">임대보증금</TD>
# <TD WIDTH="78" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30">12,926</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="161" HEIGHT="30">근저당권</TD>
# <TD WIDTH="244" HEIGHT="30">한화생명보험㈜ 등 11개 금융기관</TD>
# <TD WIDTH="93" ALIGN="RIGHT" HEIGHT="30">408,000</TD>
# <TD WIDTH="93" ALIGN="CENTER" HEIGHT="30">장기차입금</TD>
# <TD WIDTH="78" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30">340,000</TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="78" HEIGHT="30" VALIGN="MIDDLE" ALIGN="CENTER">정기예금</TD>
# <TD WIDTH="161" HEIGHT="30">예금 근질권</TD>
#
# <TD WIDTH="244" HEIGHT="30">
# <SPAN>㈜신한은행 </SPAN>
# <SPAN>등 </SPAN>
# <SPAN>7</SPAN>
# <SPAN>개사(주</SPAN>
# <SPAN>1)</SPAN>
# </TD>
# <TD WIDTH="78" HEIGHT="30" VALIGN="MIDDLE" ALIGN="RIGHT">889</TD>
# <TD WIDTH="93" ALIGN="RIGHT" HEIGHT="30">1,056</TD>
# <TD WIDTH="93" ALIGN="CENTER" HEIGHT="30">임대보증금</TD>
# <TD WIDTH="78" VALIGN="MIDDLE" ALIGN="RIGHT" HEIGHT="30">889</TD>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="0" WIDTH="828">
#
# <COLGROUP>
# <COL WIDTH="819"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="828" HEIGHT="30">주1)
# <SPAN>당사명의 계좌에 보증금을 예치하고 임차인이 근질권자인 예금근질권을 설정하였습니다.</SPAN>
# </TD>
# </TR>
# </TBODY>
# </TABLE>
# <P></P>
# <P>라. 채무인수약정 현황</P>
# <P>- 해당사항이 없습니다.</P>
# <P>&cr;마. 그 밖의 우발채무 등</P>
# <P>- 해당사항이 없습니다.&cr;&cr;바. 자본으로 인정되는 채무증권의 발행&cr;- 해당사항이 없습니다.&cr;&cr;</P>
#
# <P>
# <SPAN USERMARK="F-16 0XFF1200 B">3. 제재현황 등 그 밖의 사항</SPAN>
# </P>
# <P></P>
# <P>가. 제재현황&cr;- 해당사항이 없습니다.</P>
#
# <P>&cr;
# <SPAN>나. 작성 기준일 이후 발생한 주요사항</SPAN>
# <SPAN>&cr;- 해당사항이 없습니다.</SPAN>
# </P>
# <P></P>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆『신용보강 제공 현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*신용보강제공현황.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆『장래매출채권 유동화 현황 및 채무비중』 삽입</COMMENT>
# <LIBRARYLIST>11011#*장래매출채권유동화현황및채무비중.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆『단기매매차익 미환수 현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*단기매매차익미환수현황.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="1" ADUPLICATION="N">
# <COMMENT>◆click◆『공모자금의 사용내역』 삽입</COMMENT>
# <LIBRARYLIST>11011#*공모자금의사용내역.dsl</LIBRARYLIST>
#
# <LIBRARY>
# <FILENAME ATYPE="dsl">18_공모자금의사용내역</FILENAME>
# <P>&cr;다. 직접금융 자금의 사용&cr; 1) 공모자금의 사용내역</P>
#
# <TABLE-GROUP ACLASS="FUND" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="641" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="71"></COL>
# <COL WIDTH="143"></COL>
# <COL WIDTH="59"></COL>
# <COL WIDTH="332"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TD VALIGN="BOTTOM" WIDTH="80" HEIGHT="30" AUPDATECONT="N">(기준일 : </TD>
# <TU ALIGN="CENTER" VALIGN="BOTTOM" WIDTH="152" HEIGHT="30" AUNIT="BASE_DT" AUNITVALUE="20200930">2020.09.30</TU>
# <TD VALIGN="BOTTOM" WIDTH="68" HEIGHT="30" AUPDATECONT="N">)</TD>
# <TU ALIGN="RIGHT" VALIGN="BOTTOM" WIDTH="341" HEIGHT="30" AUNIT="WON" AUNITVALUE="1">(단위 : 원)</TU>
# </TR>
# </TBODY>
# </TABLE>
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="870" BORDER="1" FRAME="BORDER" RULES="ALL">
#
# <COLGROUP>
# <COL WIDTH="104"></COL>
# <COL WIDTH="39"></COL>
# <COL WIDTH="83"></COL>
# <COL WIDTH="104"></COL>
# <COL WIDTH="120"></COL>
# <COL WIDTH="104"></COL>
# <COL WIDTH="120"></COL>
# <COL WIDTH="124"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="113" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ROWSPAN="2">구 분</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="48" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ROWSPAN="2">회차</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="92" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ROWSPAN="2">납입일</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="242" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" COLSPAN="2">증권신고서 등의&cr; 자금사용 계획</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="242" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" COLSPAN="2">실제 자금사용&cr; 내역</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ROWSPAN="2">차이발생 사유 등</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="113" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">사용용도</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="129" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">조달금액</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="113" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">내용</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="129" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">금액</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="N">
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PO_TYPE" VALIGN="MIDDLE"> 유상증자&cr;(일반공모)</TE>
# <TE ALIGN="CENTER" WIDTH="48" HEIGHT="53" ACODE="MO_SEQ" VALIGN="MIDDLE">3</TE>
# <TU ALIGN="CENTER" WIDTH="92" HEIGHT="53" AUNIT="PYM_DT" VALIGN="MIDDLE" AUNITVALUE="20180731">2018.07.31</TU>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PLA_USE" VALIGN="MIDDLE">차입금상환 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="PLA_AMT" VALIGN="MIDDLE">114,000,000,000</TE>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="BRK_CON" VALIGN="MIDDLE">차입금상환 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="BRK_AMT" VALIGN="MIDDLE">114,000,000,000</TE>
# <TE ALIGN="CENTER" WIDTH="133" HEIGHT="53" ACODE="PS_AMT_PL" VALIGN="MIDDLE">-</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PO_TYPE" VALIGN="MIDDLE">유상증자(주1)&cr;(주주배정)</TE>
# <TE ALIGN="CENTER" WIDTH="48" HEIGHT="53" ACODE="MO_SEQ" VALIGN="MIDDLE">4</TE>
# <TU ALIGN="CENTER" WIDTH="92" HEIGHT="53" AUNIT="PYM_DT" VALIGN="MIDDLE" AUNITVALUE="20190129">2019.01.29</TU>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PLA_USE" VALIGN="MIDDLE">종속회사&cr;지분투자 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="PLA_AMT" VALIGN="MIDDLE">48,572,400,000</TE>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="BRK_CON" VALIGN="MIDDLE">종속회사&cr;지분투자 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="BRK_AMT" VALIGN="MIDDLE">48,572,400,000</TE>
# <TE ALIGN="CENTER" WIDTH="133" HEIGHT="53" ACODE="PS_AMT_PL" VALIGN="MIDDLE">-</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PO_TYPE" VALIGN="MIDDLE">유상증자(주2)&cr;(주주배정)</TE>
# <TE ALIGN="CENTER" WIDTH="48" HEIGHT="53" ACODE="MO_SEQ" VALIGN="MIDDLE">5</TE>
# <TU ALIGN="CENTER" WIDTH="92" HEIGHT="53" AUNIT="PYM_DT" VALIGN="MIDDLE" AUNITVALUE="20200527">2020.05.27</TU>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="PLA_USE" VALIGN="MIDDLE">종속회사&cr;지분투자 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="PLA_AMT" VALIGN="MIDDLE">27,542,000,000</TE>
# <TE ALIGN="CENTER" WIDTH="113" HEIGHT="53" ACODE="BRK_CON" VALIGN="MIDDLE">종속회사&cr;지분투자 등</TE>
# <TE ALIGN="RIGHT" WIDTH="129" HEIGHT="53" ACODE="BRK_AMT" VALIGN="MIDDLE">27,542,000,000</TE>
# <TE ALIGN="CENTER" WIDTH="133" HEIGHT="53" ACODE="PS_AMT_PL" VALIGN="MIDDLE">-</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" BORDER="0" WIDTH="1050">
#
# <COLGROUP>
# <COL WIDTH="1041"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="1050" HEIGHT="30">주1) 당사는
# <SPAN> 유상증자 및 보유 여유현금 등을 재원으로 종속회사인 (주)신한알파용산위탁관리부동산투자회사의 보통주식</SPAN>
# <SPAN>에 총 765억원을 투자하였습니다.</SPAN>
# </TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
#
# <TD WIDTH="1050" HEIGHT="30">주2) 당사는
# <SPAN> 유상증자 및 보유 여유현금 등을 재원으로 종속회사인 (주)신한알파광교위탁관리부동산투자회사의 보통주식</SPAN>
# <SPAN>에 총 300억원을 투자하였습니다.</SPAN>
# </TD>
# </TR>
# </TBODY>
# </TABLE>
# </LIBRARY>
# </INSERTION>
# <P></P>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆『사모자금의 사용내역』 삽입</COMMENT>
# <LIBRARYLIST>11011#*사모자금의사용내역.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="LE0" AFREQUENCY="0" ADUPLICATION="Y">
# <COMMENT>◆click◆『합병등 전후의 재무사항 비교표』 삽입</COMMENT>
# <LIBRARYLIST>11011#*합병등전후의재무사항비교표.dsl</LIBRARYLIST>
# </INSERTION>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="Y">
# <COMMENT>◆click◆『보호예수 현황』 삽입</COMMENT>
# <LIBRARYLIST>11011#*보호예수현황.dsl</LIBRARYLIST>
# </INSERTION>
# <P></P>
# <PGBRK></PGBRK>
# </SECTION-1>
#
# <SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">
# <TITLE ATOC="Y">【 전문가의 확인 】</TITLE>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-3-0-1-0">1. 전문가의 확인</TITLE>
# <P>해당사항 없음.&cr;</P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-3-0-2-0">2. 전문가와의 이해관계</TITLE>
# <P>해당사항 없음.&cr;</P>
# </SECTION-2>
# </SECTION-1>
# </BODY>
# </DOCUMENT>

# %% [markdown]
# #### Company 메서드

# %%
print(dart.company("신한알파리츠"))
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '01276594', 'corp_name': '(주)신한알파위탁관리부동산투자회사', 'corp_name_eng': 'Shinhan Alpha REIT Co,. Ltd.', 'stock_name': '신한알파리츠', 'stock_code': '293940', 'ceo_nm': '이준구', 'corp_cls': 'Y', 'jurir_no': '1101116601135', 'bizr_no': '2938100902', 'adres': '서울특별시 종로구 종로 33 그랑서울, 18층', 'hm_url': 'www.shalphareit.com', 'ir_url': 'www.shalphareit.com', 'phn_no': '02-2158-7400', 'fax_no': '02-2158-7449', 'induty_code': '6811', 'est_dt': '20171218', 'acc_mt': '03'}

# %% [markdown]
# #### Report 메서드

# %%
display(dart.report("신한알파리츠", "배당", 2020, "11011"))
# Out:
#           rcept_no corp_cls corp_code corp_name              se  thstrm  \
# 0   20200629000296        Y  01276594    신한알파리츠       주당액면가액(원)   1,000
# 1   20201229000410        Y  01276594    신한알파리츠       주당액면가액(원)   1,000
# 2   20200629000296        Y  01276594    신한알파리츠  (연결)당기순이익(백만원)   5,722
# 3   20201229000410        Y  01276594    신한알파리츠  (연결)당기순이익(백만원)   2,526
# 4   20200629000296        Y  01276594    신한알파리츠  (별도)당기순이익(백만원)   6,362
# 5   20201229000410        Y  01276594    신한알파리츠  (별도)당기순이익(백만원)   9,676
# 6   20200629000296        Y  01276594    신한알파리츠    (연결)주당순이익(원)      87
# 7   20201229000410        Y  01276594    신한알파리츠    (연결)주당순이익(원)      21
# 8   20200629000296        Y  01276594    신한알파리츠    현금배당금총액(백만원)   8,797
# 9   20201229000410        Y  01276594    신한알파리츠    현금배당금총액(백만원)   9,654
# 10  20200629000296        Y  01276594    신한알파리츠    주식배당금총액(백만원)       -
# 11  20201229000410        Y  01276594    신한알파리츠    주식배당금총액(백만원)       -
# 12  20200629000296        Y  01276594    신한알파리츠   (연결)현금배당성향(%)  153.70
# 13  20201229000410        Y  01276594    신한알파리츠   (연결)현금배당성향(%)  382.20
# 14  20200629000296        Y  01276594    신한알파리츠      현금배당수익률(%)    2.40
# 15  20200629000296        Y  01276594    신한알파리츠      현금배당수익률(%)    2.80
# 16  20200629000296        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 17  20200629000296        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 18  20200629000296        Y  01276594    신한알파리츠     주당 현금배당금(원)     150
# 19  20200629000296        Y  01276594    신한알파리츠     주당 현금배당금(원)     413
# 20  20200629000296        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 21  20200629000296        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 22  20201229000410        Y  01276594    신한알파리츠      현금배당수익률(%)    2.30
# 23  20201229000410        Y  01276594    신한알파리츠      현금배당수익률(%)    2.70
# 24  20201229000410        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 25  20201229000410        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 26  20201229000410        Y  01276594    신한알파리츠     주당 현금배당금(원)     153
# 27  20201229000410        Y  01276594    신한알파리츠     주당 현금배당금(원)     412
# 28  20201229000410        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 29  20201229000410        Y  01276594    신한알파리츠      주당 주식배당(주)       -
#
#     frmtrm    lwfr stock_knd
# 0    1,000   1,000       NaN
# 1    1,000   1,000       NaN
# 2    3,017   5,075       NaN
# 3    5,722   3,017       NaN
# 4    5,906   5,787       NaN
# 5    6,362   5,906       NaN
# 6       29      83       NaN
# 7       87      29       NaN
# 8    8,324   8,169       NaN
# 9    8,797   8,324       NaN
# 10       -       -       NaN
# 11       -       -       NaN
# 12  275.90  160.90       NaN
# 13  153.70  275.90       NaN
# 14    1.80    2.30       보통주
# 15    2.80    2.70       종류주
# 16       -       -       보통주
# 17       -       -       종류주
# 18     140     137       보통주
# 19     414     411       종류주
# 20       -       -       보통주
# 21       -       -       종류주
# 22    2.40    1.80       보통주
# 23    2.80    2.80       종류주
# 24       -       -       보통주
# 25       -       -       종류주
# 26     150     140       보통주
# 27     413     414       종류주
# 28       -       -       보통주
# 29       -       -       종류주

# %% [markdown]
# #### Finstate 메서드

# %%
result = dart.finstate("신한알파리츠", 2020, "11011") 
result = result.loc[result["fs_nm"] == "연결재무제표"] 
result = result.loc[result["account_nm"].isin(["당기순이익", "영업이익", "매출액"])] 
result = result.loc[:, ["account_nm", "fs_nm", "sj_nm", "thstrm_dt", "thstrm_amount"]]
display(result)
# Out:
#    account_nm   fs_nm  sj_nm                thstrm_dt   thstrm_amount
# 9        영업이익  연결재무제표  손익계산서  2020.04.01 ~ 2020.09.30  13,350,362,969
# 11      당기순이익  연결재무제표  손익계산서  2020.04.01 ~ 2020.09.30   2,526,240,050

# %% [markdown]
# #### 배당보고서 탐색

# %%
# 신한알파리츠
Shinhan_alpha_report = dart.report("신한알파리츠", "배당", 2020, "11011")
display(Shinhan_alpha_report)
# Out:
#           rcept_no corp_cls corp_code corp_name              se  thstrm  \
# 0   20200629000296        Y  01276594    신한알파리츠       주당액면가액(원)   1,000
# 1   20201229000410        Y  01276594    신한알파리츠       주당액면가액(원)   1,000
# 2   20200629000296        Y  01276594    신한알파리츠  (연결)당기순이익(백만원)   5,722
# 3   20201229000410        Y  01276594    신한알파리츠  (연결)당기순이익(백만원)   2,526
# 4   20200629000296        Y  01276594    신한알파리츠  (별도)당기순이익(백만원)   6,362
# 5   20201229000410        Y  01276594    신한알파리츠  (별도)당기순이익(백만원)   9,676
# 6   20200629000296        Y  01276594    신한알파리츠    (연결)주당순이익(원)      87
# 7   20201229000410        Y  01276594    신한알파리츠    (연결)주당순이익(원)      21
# 8   20200629000296        Y  01276594    신한알파리츠    현금배당금총액(백만원)   8,797
# 9   20201229000410        Y  01276594    신한알파리츠    현금배당금총액(백만원)   9,654
# 10  20200629000296        Y  01276594    신한알파리츠    주식배당금총액(백만원)       -
# 11  20201229000410        Y  01276594    신한알파리츠    주식배당금총액(백만원)       -
# 12  20200629000296        Y  01276594    신한알파리츠   (연결)현금배당성향(%)  153.70
# 13  20201229000410        Y  01276594    신한알파리츠   (연결)현금배당성향(%)  382.20
# 14  20200629000296        Y  01276594    신한알파리츠      현금배당수익률(%)    2.40
# 15  20200629000296        Y  01276594    신한알파리츠      현금배당수익률(%)    2.80
# 16  20200629000296        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 17  20200629000296        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 18  20200629000296        Y  01276594    신한알파리츠     주당 현금배당금(원)     150
# 19  20200629000296        Y  01276594    신한알파리츠     주당 현금배당금(원)     413
# 20  20200629000296        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 21  20200629000296        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 22  20201229000410        Y  01276594    신한알파리츠      현금배당수익률(%)    2.30
# 23  20201229000410        Y  01276594    신한알파리츠      현금배당수익률(%)    2.70
# 24  20201229000410        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 25  20201229000410        Y  01276594    신한알파리츠      주식배당수익률(%)       -
# 26  20201229000410        Y  01276594    신한알파리츠     주당 현금배당금(원)     153
# 27  20201229000410        Y  01276594    신한알파리츠     주당 현금배당금(원)     412
# 28  20201229000410        Y  01276594    신한알파리츠      주당 주식배당(주)       -
# 29  20201229000410        Y  01276594    신한알파리츠      주당 주식배당(주)       -
#
#     frmtrm    lwfr stock_knd
# 0    1,000   1,000       NaN
# 1    1,000   1,000       NaN
# 2    3,017   5,075       NaN
# 3    5,722   3,017       NaN
# 4    5,906   5,787       NaN
# 5    6,362   5,906       NaN
# 6       29      83       NaN
# 7       87      29       NaN
# 8    8,324   8,169       NaN
# 9    8,797   8,324       NaN
# 10       -       -       NaN
# 11       -       -       NaN
# 12  275.90  160.90       NaN
# 13  153.70  275.90       NaN
# 14    1.80    2.30       보통주
# 15    2.80    2.70       종류주
# 16       -       -       보통주
# 17       -       -       종류주
# 18     140     137       보통주
# 19     414     411       종류주
# 20       -       -       보통주
# 21       -       -       종류주
# 22    2.40    1.80       보통주
# 23    2.80    2.80       종류주
# 24       -       -       보통주
# 25       -       -       종류주
# 26     150     140       보통주
# 27     413     414       종류주
# 28       -       -       보통주
# 29       -       -       종류주

# %%
# 코람코에너지리츠
Koramco_energy_report = dart.report("코람코에너지리츠", "배당", 2020, "11011")
display(Koramco_energy_report)
# Out:
#           rcept_no corp_cls corp_code corp_name              se thstrm frmtrm  \
# 0   20210216000688        Y  01430475  코람코에너지리츠       주당액면가액(원)    500      -
# 1   20210216000688        Y  01430475  코람코에너지리츠  (연결)당기순이익(백만원)      -      -
# 2   20210216000688        Y  01430475  코람코에너지리츠  (별도)당기순이익(백만원)      -      -
# 3   20210216000688        Y  01430475  코람코에너지리츠    (연결)주당순이익(원)      -      -
# 4   20210216000688        Y  01430475  코람코에너지리츠    현금배당금총액(백만원)  9,173      -
# 5   20210216000688        Y  01430475  코람코에너지리츠    주식배당금총액(백만원)      -      -
# 6   20210216000688        Y  01430475  코람코에너지리츠   (연결)현금배당성향(%)      -      -
# 7   20210216000688        Y  01430475  코람코에너지리츠      현금배당수익률(%)   2.70      -
# 8   20210216000688        Y  01430475  코람코에너지리츠      현금배당수익률(%)      -      -
# 9   20210216000688        Y  01430475  코람코에너지리츠      주식배당수익률(%)      -      -
# 10  20210216000688        Y  01430475  코람코에너지리츠      주식배당수익률(%)      -      -
# 11  20210216000688        Y  01430475  코람코에너지리츠     주당 현금배당금(원)    131      -
# 12  20210216000688        Y  01430475  코람코에너지리츠     주당 현금배당금(원)      -      -
# 13  20210216000688        Y  01430475  코람코에너지리츠      주당 주식배당(주)      -      -
# 14  20210216000688        Y  01430475  코람코에너지리츠      주당 주식배당(주)      -      -
#
#    lwfr stock_knd
# 0     -       NaN
# 1     -       NaN
# 2     -       NaN
# 3     -       NaN
# 4     -       NaN
# 5     -       NaN
# 6     -       NaN
# 7     -      보통주식
# 8     -       NaN
# 9     -       NaN
# 10    -       NaN
# 11    -      보통주식
# 12    -       NaN
# 13    -       NaN
# 14    -       NaN

# %%
# 롯데리츠
Lotte_reit_report = dart.report("롯데리츠", "배당", 2020, "11011")
display(Lotte_reit_report)
# Out:
#           rcept_no corp_cls corp_code corp_name              se  thstrm  \
# 0   20200928000189        Y  01363818      롯데리츠       주당액면가액(원)     500
# 1   20210322000656        Y  01363818      롯데리츠       주당액면가액(원)     500
# 2   20200928000189        Y  01363818      롯데리츠  (연결)당기순이익(백만원)       -
# 3   20210322000656        Y  01363818      롯데리츠  (연결)당기순이익(백만원)       -
# 4   20200928000189        Y  01363818      롯데리츠  (별도)당기순이익(백만원)       -
# 5   20210322000656        Y  01363818      롯데리츠  (별도)당기순이익(백만원)       -
# 6   20200928000189        Y  01363818      롯데리츠    (연결)주당순이익(원)       -
# 7   20210322000656        Y  01363818      롯데리츠    (연결)주당순이익(원)       -
# 8   20200928000189        Y  01363818      롯데리츠    현금배당금총액(백만원)  27,778
# 9   20210322000656        Y  01363818      롯데리츠    현금배당금총액(백만원)  27,838
# 10  20200928000189        Y  01363818      롯데리츠    주식배당금총액(백만원)       -
# 11  20210322000656        Y  01363818      롯데리츠    주식배당금총액(백만원)       -
# 12  20200928000189        Y  01363818      롯데리츠   (연결)현금배당성향(%)       -
# 13  20210322000656        Y  01363818      롯데리츠   (연결)현금배당성향(%)       -
# 14  20200928000189        Y  01363818      롯데리츠      현금배당수익률(%)    2.88
# 15  20200928000189        Y  01363818      롯데리츠      현금배당수익률(%)       -
# 16  20200928000189        Y  01363818      롯데리츠      주식배당수익률(%)       -
# 17  20200928000189        Y  01363818      롯데리츠      주식배당수익률(%)       -
# 18  20200928000189        Y  01363818      롯데리츠     주당 현금배당금(원)     161
# 19  20200928000189        Y  01363818      롯데리츠     주당 현금배당금(원)       -
# 20  20200928000189        Y  01363818      롯데리츠      주당 주식배당(주)       -
# 21  20200928000189        Y  01363818      롯데리츠      주당 주식배당(주)       -
# 22  20210322000656        Y  01363818      롯데리츠      현금배당수익률(%)    2.99
# 23  20210322000656        Y  01363818      롯데리츠      현금배당수익률(%)       -
# 24  20210322000656        Y  01363818      롯데리츠      주식배당수익률(%)       -
# 25  20210322000656        Y  01363818      롯데리츠      주식배당수익률(%)       -
# 26  20210322000656        Y  01363818      롯데리츠     주당 현금배당금(원)     161
# 27  20210322000656        Y  01363818      롯데리츠     주당 현금배당금(원)       -
# 28  20210322000656        Y  01363818      롯데리츠      주당 주식배당(주)       -
# 29  20210322000656        Y  01363818      롯데리츠      주당 주식배당(주)       -
#
#     frmtrm    lwfr stock_knd
# 0      500     500       NaN
# 1      500     500       NaN
# 2        -       -       NaN
# 3        -       -       NaN
# 4        -       -       NaN
# 5        -       -       NaN
# 6        -       -       NaN
# 7        -       -       NaN
# 8   16,588   1,825       NaN
# 9   27,778  16,588       NaN
# 10       -       -       NaN
# 11       -       -       NaN
# 12       -       -       NaN
# 13       -       -       NaN
# 14    1.54       -      보통주식
# 15       -       -       NaN
# 16       -       -       NaN
# 17       -       -       NaN
# 18      96      21      보통주식
# 19       -       -       NaN
# 20       -       -       NaN
# 21       -       -       NaN
# 22    2.87    1.54      보통주식
# 23       -       -       NaN
# 24       -       -       NaN
# 25       -       -       NaN
# 26     161      96      보통주식
# 27       -       -       NaN
# 28       -       -       NaN
# 29       -       -       NaN

# %% [markdown]
# ## 데이터 파싱
#
# #### 데이터 파싱 함수 작성

# %%
import numpy as np
def find_div_and_EPS(stock, year):
    report = dart.report(stock, "배당", year, "11011") # 데이터 가져오기
    output = dict() # 출력 초기화
    if report is None: # 리포트가 없다면 (참고: 리포트가 없으면 None을 반환함)
        output['주당배당금'] = np.nan, np.nan, np.nan
        output['주당순이익'] = np.nan, np.nan, np.nan
    
    else:
        # 주당배당금 (div) 관련 행 필터링
        div_row = report.loc[(report['se'] == '주당 현금배당금(원)')].iloc[0]
        
        # 전전기(second previous: spre), 전기(previous: pre), 당기(current: cur)
        # 하이픈 0으로 변환 및 콤마 제거
        cur_div = int(div_row['thstrm'].replace('-', '0').replace(',', '')) 
        pre_div = int(div_row['frmtrm'].replace('-', '0').replace(',', ''))
        spre_div = int(div_row['lwfr'].replace('-', '0').replace(',', '')) 
        output['주당배당금'] = spre_div, pre_div, cur_div
        
        # 주당순이익 (EPS) 관련 행 필터링
        EPS_row = report.loc[(report['se'].str.contains('주당순이익'))].iloc[0]
        
        # 하이픈 0으로 변환 및 콤마 제거
        cur_EPS = int(EPS_row['thstrm'].replace('-', '0').replace(',', '')) 
        pre_EPS = int(EPS_row['frmtrm'].replace('-', '0').replace(',', ''))
        spre_EPS = int(EPS_row['lwfr'].replace('-', '0').replace(',', '')) 
        output['주당순이익'] = spre_EPS, pre_EPS, cur_EPS

    return output

# %%
print(find_div_and_EPS("신한알파리츠", 2020))
# Out:
# {'주당배당금': (137, 140, 150), '주당순이익': (83, 29, 87)}
